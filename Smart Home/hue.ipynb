# %%
from phue import Bridge

# %%
b = Bridge('192.168.0.151')

# %%
b.connect()

# %%
b.get_api()
# Out:
# {'lights': {'1': {'state': {'on': True,
#     'bri': 254,
#     'hue': 0,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.6915, 0.3083],
#     'ct': 500,
#     'alert': 'select',
#     'colormode': 'xy',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2023-08-17T08:15:51'},
#    'type': 'Extended color light',
#    'name': 'Big lamp 1',
#    'modelid': 'LCT016',
#    'manufacturername': 'Signify Netherlands B.V.',
#    'productname': 'Hue color lamp',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 1000,
#      'maxlumen': 800,
#      'colorgamuttype': 'C',
#      'colorgamut': [[0.6915, 0.3083], [0.17, 0.7], [0.1532, 0.0475]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': True}},
#    'config': {'archetype': 'tableshade',
#     'function': 'mixed',
#     'direction': 'omnidirectional',
#     'startup': {'mode': 'custom',
#      'configured': True,
#      'customsettings': {'bri': 254, 'ct': 500}}},
#    'uniqueid': '00:17:88:01:03:b1:c5:28-0b',
#    'swversion': '1.108.5',
#    'swconfigid': '91925CAC',
#    'productid': 'Philips-LCT016-1-A19ECLv5'},
#   '2': {'state': {'on': True,
#     'bri': 254,
#     'hue': 12357,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.4398, 0.4974],
#     'ct': 337,
#     'alert': 'select',
#     'colormode': 'xy',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2023-08-17T08:16:07'},
#    'type': 'Extended color light',
#    'name': 'Table lamp',
#    'modelid': 'LCT016',
#    'manufacturername': 'Signify Netherlands B.V.',
#    'productname': 'Hue color lamp',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 1000,
#      'maxlumen': 800,
#      'colorgamuttype': 'C',
#      'colorgamut': [[0.6915, 0.3083], [0.17, 0.7], [0.1532, 0.0475]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': True}},
#    'config': {'archetype': 'floorshade',
#     'function': 'mixed',
#     'direction': 'omnidirectional',
#     'startup': {'mode': 'custom',
#      'configured': True,
#      'customsettings': {'bri': 254, 'ct': 500}}},
#    'uniqueid': '00:17:88:01:03:d1:63:84-0b',
#    'swversion': '1.108.5',
#    'swconfigid': '91925CAC',
#    'productid': 'Philips-LCT016-1-A19ECLv5'},
#   '4': {'state': {'on': True,
#     'bri': 254,
#     'hue': 9519,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.4976, 0.4539],
#     'ct': 436,
#     'alert': 'select',
#     'colormode': 'xy',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2023-08-17T08:16:04'},
#    'type': 'Extended color light',
#    'name': 'Big lamp 3',
#    'modelid': 'LCT016',
#    'manufacturername': 'Signify Netherlands B.V.',
#    'productname': 'Hue color lamp',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 1000,
#      'maxlumen': 800,
#      'colorgamuttype': 'C',
#      'colorgamut': [[0.6915, 0.3083], [0.17, 0.7], [0.1532, 0.0475]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': True}},
#    'config': {'archetype': 'floorshade',
#     'function': 'mixed',
#     'direction': 'omnidirectional',
#     'startup': {'mode': 'custom',
#      'configured': True,
#      'customsettings': {'bri': 254, 'ct': 500}}},
#    'uniqueid': '00:17:88:01:03:d4:09:a5-0b',
#    'swversion': '1.108.5',
#    'swconfigid': '91925CAC',
#    'productid': 'Philips-LCT016-1-A19ECLv5'},
#   '5': {'state': {'on': True,
#     'bri': 254,
#     'hue': 7208,
#     'sat': 223,
#     'effect': 'none',
#     'xy': [0.5249, 0.4136],
#     'ct': 497,
#     'alert': 'select',
#     'colormode': 'ct',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2023-08-17T08:15:37'},
#    'type': 'Extended color light',
#    'name': 'Living room Light',
#    'modelid': 'LCT016',
#    'manufacturername': 'Signify Netherlands B.V.',
#    'productname': 'Hue color lamp',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 1000,
#      'maxlumen': 800,
#      'colorgamuttype': 'C',
#      'colorgamut': [[0.6915, 0.3083], [0.17, 0.7], [0.1532, 0.0475]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': True}},
#    'config': {'archetype': 'floorshade',
#     'function': 'mixed',
#     'direction': 'omnidirectional',
#     'startup': {'mode': 'custom',
#      'configured': True,
#      'customsettings': {'bri': 254, 'ct': 500}}},
#    'uniqueid': '00:17:88:01:03:b9:77:6b-0b',
#    'swversion': '1.108.5',
#    'swconfigid': '91925CAC',
#    'productid': 'Philips-LCT016-1-A19ECLv5'},
#   '6': {'state': {'on': True,
#     'bri': 254,
#     'hue': 7208,
#     'sat': 223,
#     'effect': 'none',
#     'xy': [0.5249, 0.4136],
#     'ct': 497,
#     'alert': 'select',
#     'colormode': 'ct',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2023-05-24T08:06:44'},
#    'type': 'Extended color light',
#    'name': 'Living room Light',
#    'modelid': 'LCA003',
#    'manufacturername': 'Signify Netherlands B.V.',
#    'productname': 'Hue color Lamp',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 200,
#      'maxlumen': 800,
#      'colorgamuttype': 'C',
#      'colorgamut': [[0.6915, 0.3083], [0.17, 0.7], [0.1532, 0.0475]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': True}},
#    'config': {'archetype': 'floorshade',
#     'function': 'mixed',
#     'direction': 'omnidirectional',
#     'startup': {'mode': 'custom',
#      'configured': True,
#      'customsettings': {'bri': 254, 'ct': 500}}},
#    'uniqueid': '00:17:88:01:08:9c:b6:f1-0b',
#    'swversion': '1.104.2',
#    'swconfigid': '4FD50FDB',
#    'productid': 'Philips-LCA003-1-A19ECLv6'},
#   '7': {'state': {'on': True,
#     'bri': 254,
#     'hue': 37545,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.2745, 0.2525],
#     'ct': 153,
#     'alert': 'select',
#     'colormode': 'xy',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2023-08-17T08:16:27'},
#    'type': 'Extended color light',
#    'name': 'Big lamp 2',
#    'modelid': 'LCT003',
#    'manufacturername': 'Signify Netherlands B.V.',
#    'productname': 'Hue color spot',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 5000,
#      'maxlumen': 250,
#      'colorgamuttype': 'B',
#      'colorgamut': [[0.675, 0.322], [0.409, 0.518], [0.167, 0.04]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': True}},
#    'config': {'archetype': 'floorshade',
#     'function': 'mixed',
#     'direction': 'downwards',
#     'startup': {'mode': 'custom',
#      'configured': True,
#      'customsettings': {'bri': 254, 'ct': 500}}},
#    'uniqueid': '00:17:88:01:04:dc:ca:66-0b',
#    'swversion': '67.108.5'},
#   '8': {'state': {'on': False,
#     'bri': 251,
#     'hue': 7409,
#     'sat': 225,
#     'effect': 'none',
#     'xy': [0.5223, 0.4165],
#     'ct': 488,
#     'alert': 'select',
#     'colormode': 'xy',
#     'mode': 'homeautomation',
#     'reachable': True},
#    'swupdate': {'state': 'noupdates', 'lastinstall': '2023-05-24T08:07:08'},
#    'type': 'Extended color light',
#    'name': 'Afro’s',
#    'modelid': 'LCA003',
#    'manufacturername': 'Signify Netherlands B.V.',
#    'productname': 'Hue color Lamp',
#    'capabilities': {'certified': True,
#     'control': {'mindimlevel': 200,
#      'maxlumen': 800,
#      'colorgamuttype': 'C',
#      'colorgamut': [[0.6915, 0.3083], [0.17, 0.7], [0.1532, 0.0475]],
#      'ct': {'min': 153, 'max': 500}},
#     'streaming': {'renderer': True, 'proxy': True}},
#    'config': {'archetype': 'floorshade',
#     'function': 'mixed',
#     'direction': 'omnidirectional',
#     'startup': {'mode': 'custom',
#      'configured': True,
#      'customsettings': {'bri': 254, 'ct': 499}}},
#    'uniqueid': '00:17:88:01:08:7f:e3:5c-0b',
#    'swversion': '1.104.2',
#    'swconfigid': '4FD50FDB',
#    'productid': 'Philips-LCA003-1-A19ECLv6'}},
#  'groups': {'1': {'name': 'Salman Bedroom',
#    'lights': ['2', '4', '1', '7'],
#    'sensors': [],
#    'type': 'Room',
#    'state': {'all_on': True, 'any_on': True},
#    'recycle': False,
#    'class': 'Bedroom',
#    'action': {'on': True,
#     'bri': 254,
#     'hue': 37545,
#     'sat': 254,
#     'effect': 'none',
#     'xy': [0.2745, 0.2525],
#     'ct': 153,
#     'alert': 'select',
#     'colormode': 'xy'}},
#   '3': {'name': 'Living Room',
#    'lights': ['6', '5'],
#    'sensors': [],
#    'type': 'Room',
#    'state': {'all_on': True, 'any_on': True},
#    'recycle': False,
#    'class': 'Living room',
#    'action': {'on': True,
#     'bri': 254,
#     'hue': 7208,
#     'sat': 223,
#     'effect': 'none',
#     'xy': [0.5249, 0.4136],
#     'ct': 497,
#     'alert': 'select',
#     'colormode': 'ct'}},
#   '4': {'name': 'Afro’s',
#    'lights': ['8'],
#    'sensors': [],
#    'type': 'Room',
#    'state': {'all_on': False, 'any_on': False},
#    'recycle': False,
#    'class': 'Living room',
#    'action': {'on': False,
#     'bri': 251,
#     'hue': 7409,
#     'sat': 225,
#     'effect': 'none',
#     'xy': [0.5223, 0.4165],
#     'ct': 488,
#     'alert': 'select',
#     'colormode': 'xy'}}},
#  'config': {'name': 'Hue Bridge',
#   'zigbeechannel': 15,
#   'bridgeid': '001788FFFEADA998',
#   'mac': '00:17:88:ad:a9:98',
#   'dhcp': True,
#   'ipaddress': '192.168.0.151',
#   'netmask': '255.255.255.0',
#   'gateway': '192.168.0.1',
#   'proxyaddress': 'none',
#   'proxyport': 0,
#   'UTC': '2023-09-24T07:35:59',
#   'localtime': '2023-09-24T03:35:59',
#   'timezone': 'America/Toronto',
#   'modelid': 'BSB002',
#   'datastoreversion': '162',
#   'swversion': '1960062030',
#   'apiversion': '1.60.0',
#   'swupdate2': {'checkforupdate': False,
#    'lastchange': '2023-09-22T08:40:15',
#    'bridge': {'state': 'noupdates', 'lastinstall': '2023-09-22T08:40:15'},
#    'state': 'noupdates',
#    'autoinstall': {'updatetime': 'T04:00:00', 'on': True}},
#   'linkbutton': False,
#   'portalservices': True,
#   'portalconnection': 'disconnected',
#   'portalstate': {'signedon': False,
#    'incoming': False,
#    'outgoing': False,
#    'communication': 'disconnected'},
#   'internetservices': {'internet': 'connected',
#    'remoteaccess': 'connected',
#    'time': 'connected',
#    'swupdate': 'connected'},
#   'factorynew': False,
#   'replacesbridgeid': None,
#   'starterkitid': '',
#   'backup': {'status': 'idle', 'errorcode': 0},
#   'whitelist': {'12035b05-3086-43a6-89ef-08b334cfbcd5': {'last use date': '2021-06-26T06:58:44',
#     'create date': '2019-07-13T00:37:36',
#     'name': 'Hue 3#Salman’s iPhone'},
#    'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c': {'last use date': '2023-09-24T06:53:18',
#     'create date': '2019-07-13T18:58:41',
#     'name': 'Hue 3#Salman’s iPhone'},
#    '37890711-4e74-4ab5-a495-f73bbacde9f3': {'last use date': '2023-09-24T07:35:26',
#     'create date': '2019-07-20T04:20:46',
#     'name': 'hue-hca-actions-on-google'},
#    '839b3c5a-8b3f-4fd0-9287-d9b6372af196': {'last use date': '2021-08-24T03:30:47',
#     'create date': '2019-09-19T15:11:13',
#     'name': 'iftttv2'},
#    '4bf7666b-f913-418f-9167-903f7b9b1d67': {'last use date': '2019-11-30T07:49:36',
#     'create date': '2019-11-30T07:48:39',
#     'name': 'huelabs-2'},
#    '031ff7e5-fba2-4979-91d4-0658b35ac950': {'last use date': '2023-09-20T22:41:22',
#     'create date': '2019-12-08T19:29:24',
#     'name': 'Hue 3#Afro'},
#    'b5f839b4-64b1-425e-98a5-abdb4ef3b297': {'last use date': '2021-09-25T04:07:11',
#     'create date': '2021-09-08T23:45:53',
#     'name': 'Hue#Dania'},
#    '077a383a-a1ad-4667-b898-90ba6b48a338': {'last use date': '2023-09-11T21:00:43',
#     'create date': '2023-07-24T00:30:30',
#     'name': 'Hue#iPad'},
#    'GdZK97JlcITfi3q4g6xKaR89RknHi51ae6B4f9Yi': {'last use date': '2023-09-24T07:35:59',
#     'create date': '2023-09-23T01:45:22',
#     'name': 'python_hue'}}},
#  'schedules': {'1': {'name': 'Candlelight romance',
#    'description': '19:recurringTimer ',
#    'command': {'address': '/api/0/groups/1/action',
#     'body': {'scene': 'vY10U4VToDHaESy'},
#     'method': 'PUT'},
#    'localtime': 'R/PT00:00:06A00:00:03',
#    'time': 'R/PT00:00:06A00:00:03',
#    'created': '2019-11-30T07:49:12',
#    'status': 'disabled',
#    'starttime': '2019-11-30T07:49:27',
#    'recycle': True},
#   '2': {'name': 'Candlelight romance',
#    'description': '20:recurringTimer ',
#    'command': {'address': '/api/0/groups/1/action',
#     'body': {'scene': 'OqtipB0Ni-FkLbZ'},
#     'method': 'PUT'},
#    'localtime': 'R/PT00:00:06A00:00:03',
#    'time': 'R/PT00:00:06A00:00:03',
#    'created': '2019-11-30T07:49:13',
#    'status': 'disabled',
#    'starttime': '2019-11-30T07:49:27',
#    'recycle': True},
#   '3': {'name': 'Candlelight romance',
#    'description': '21:recurringTimer ',
#    'command': {'address': '/api/0/groups/1/action',
#     'body': {'scene': 'bYuaqYrg1aqtwIE'},
#     'method': 'PUT'},
#    'localtime': 'R/PT00:00:06A00:00:03',
#    'time': 'R/PT00:00:06A00:00:03',
#    'created': '2019-11-30T07:49:13',
#    'status': 'disabled',
#    'starttime': '2019-11-30T07:49:27',
#    'recycle': True},
#   '4': {'name': 'Candlelight romance',
#    'description': '22:recurringTimer ',
#    'command': {'address': '/api/0/groups/1/action',
#     'body': {'scene': 'Vj4Ab8W1QTNMORL'},
#     'method': 'PUT'},
#    'localtime': 'R/PT00:00:06A00:00:03',
#    'time': 'R/PT00:00:06A00:00:03',
#    'created': '2019-11-30T07:49:13',
#    'status': 'disabled',
#    'starttime': '2019-11-30T07:49:27',
#    'recycle': True},
#   '5': {'name': 'Candlelight romance',
#    'description': '23:recurringTimer ',
#    'command': {'address': '/api/0/groups/1/action',
#     'body': {'bri': 191, 'on': True, 'transitiontime': 4},
#     'method': 'PUT'},
#    'localtime': 'R/PT00:00:10A00:00:05',
#    'time': 'R/PT00:00:10A00:00:05',
#    'created': '2019-11-30T07:49:14',
#    'status': 'disabled',
#    'starttime': '2019-11-30T07:49:27',
#    'recycle': True}},
#  'scenes': {'W0M-pVxUQ8SO8Lu': {'name': 'Relax',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'Q8OvE_r01_d01'},
#    'picture': '',
#    'image': 'a1f7da49-d181-4328-abea-68c9dc4b5416',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'FudGH72Woq-pH95': {'name': 'Read',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'uxpRr_r01_d02'},
#    'picture': '',
#    'image': 'e101a77f-9984-4f61-aac8-15741983c656',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'yFHFVvHcIKS4CtS': {'name': 'Concentrate',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'flZZ2_r01_d03'},
#    'picture': '',
#    'image': 'b90c8900-a6b7-422c-a5d3-e170187dbf8c',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   '3tRFzznAH36bz5K': {'name': 'Energize',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': '8bAFl_r01_d04'},
#    'picture': '',
#    'image': '7fd2ccc5-5749-4142-b7a5-66405a676f03',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'uAUsif16LaiuwaT': {'name': 'Bright',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'QHylc_r01_d05'},
#    'picture': '',
#    'image': '732ff1d9-76a7-4630-aad0-c8acc499bb0b',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'YHYEuQL2z0AfaOk': {'name': 'Dimmed',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'J0Ylw_r01_d06'},
#    'picture': '',
#    'image': '8c74b9ba-6e89-4083-a2a7-b10a1e566fed',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'KIP8x-IKzaRbnXR': {'name': 'Nightlight',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'kCuCZ_r01_d07'},
#    'picture': '',
#    'image': '28bbfeff-1a0c-444e-bb4b-0b74b88e0c95',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   '9sRMpq083xrBCFQ': {'name': 'Savanna sunset',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'b9A5t_r01_d15'},
#    'picture': '',
#    'image': '4f2ed241-5aea-4c9d-8028-55d2b111e06f',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'gMbcvCp8AWpopb-': {'name': 'Tropical twilight',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'a7AQE_r01_d16'},
#    'picture': '',
#    'image': 'a6a03e6a-fe6e-45bc-b686-878137f3ba91',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   '5gewr1YB06bPRW1': {'name': 'Arctic aurora',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'TfOIF_r01_d17'},
#    'picture': '',
#    'image': '1e42b2e8-d02e-40d2-9c8d-b1fd8216c686',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'bHwEePZUgKmobCB': {'name': 'Spring blossom',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'yC3E3_r01_d18'},
#    'picture': '',
#    'image': 'adfa9c3e-e9aa-4b65-b9d3-c5b2c0576715',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'xd6o9uNhCFWTnT9': {'name': 'Starlight',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'lmtAi_r01'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'Oy3N5MW4KFBXGuC': {'name': 'Scene storageScene ',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'recycle': True,
#    'locked': True,
#    'appdata': {},
#    'picture': '',
#    'lastupdated': '2019-11-30T07:49:26',
#    'version': 2},
#   'v0ZQEqs4GoLPxor': {'name': 'Chillin like a villian ',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'dCFKR_r01_d99'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'gokZvKXpl-qZ4fS': {'name': 'Normal',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'Ryo9d_r01_d99'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'vY10U4VToDHaESy': {'name': 'Scene myScene1 ',
#    'type': 'LightScene',
#    'lights': ['1', '2', '4', '5'],
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'recycle': True,
#    'locked': True,
#    'appdata': {},
#    'picture': '',
#    'lastupdated': '2019-11-30T07:49:08',
#    'version': 2},
#   'OqtipB0Ni-FkLbZ': {'name': 'Scene myScene2 ',
#    'type': 'LightScene',
#    'lights': ['1', '2', '4', '5'],
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'recycle': True,
#    'locked': True,
#    'appdata': {},
#    'picture': '',
#    'lastupdated': '2019-11-30T07:49:09',
#    'version': 2},
#   'bYuaqYrg1aqtwIE': {'name': 'Scene myScene3 ',
#    'type': 'LightScene',
#    'lights': ['1', '2', '4', '5'],
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'recycle': True,
#    'locked': True,
#    'appdata': {},
#    'picture': '',
#    'lastupdated': '2019-11-30T07:49:11',
#    'version': 2},
#   'Vj4Ab8W1QTNMORL': {'name': 'Scene myScene4 ',
#    'type': 'LightScene',
#    'lights': ['1', '2', '4', '5'],
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'recycle': True,
#    'locked': True,
#    'appdata': {},
#    'picture': '',
#    'lastupdated': '2019-11-30T07:49:12',
#    'version': 2},
#   'kN56rkTo7CFahA4': {'name': 'Relax',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'uA7nz_r03_d01'},
#    'picture': '',
#    'image': 'a1f7da49-d181-4328-abea-68c9dc4b5416',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   '6VwP-5mbTLrlsvt': {'name': 'Read',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': '5d1X2_r03_d02'},
#    'picture': '',
#    'image': 'e101a77f-9984-4f61-aac8-15741983c656',
#    'lastupdated': '2023-09-22T08:40:27',
#    'version': 2},
#   '4dVIILgEvGIPgn0': {'name': 'Concentrate',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'cSuVg_r03_d03'},
#    'picture': '',
#    'image': 'b90c8900-a6b7-422c-a5d3-e170187dbf8c',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'zo1glthKPNZZ-l9': {'name': 'Energize',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'g6EAP_r03_d04'},
#    'picture': '',
#    'image': '7fd2ccc5-5749-4142-b7a5-66405a676f03',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'QCy0vnftIVsYw9N': {'name': 'Bright',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'ElGz2_r03_d05'},
#    'picture': '',
#    'image': '732ff1d9-76a7-4630-aad0-c8acc499bb0b',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'mPE8P8W-TSXSih5': {'name': 'Dimmed',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'N1n3z_r03_d06'},
#    'picture': '',
#    'image': '8c74b9ba-6e89-4083-a2a7-b10a1e566fed',
#    'lastupdated': '2023-09-22T08:40:27',
#    'version': 2},
#   'S5qK-p53LPcSxBh': {'name': 'Nightlight',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'EOIxC_r03_d07'},
#    'picture': '',
#    'image': '28bbfeff-1a0c-444e-bb4b-0b74b88e0c95',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   '41cLSNpD8m3g5ba': {'name': 'Savanna sunset',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'OryfT_r03_d15'},
#    'picture': '',
#    'image': '4f2ed241-5aea-4c9d-8028-55d2b111e06f',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'QfJVMQKerfqhz6e': {'name': 'Tropical twilight',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'RXisu_r03_d16'},
#    'picture': '',
#    'image': 'a6a03e6a-fe6e-45bc-b686-878137f3ba91',
#    'lastupdated': '2023-09-22T08:40:27',
#    'version': 2},
#   'yKfc82l6mfMfydg': {'name': 'Arctic aurora',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': '7vR3A_r03_d17'},
#    'picture': '',
#    'image': '1e42b2e8-d02e-40d2-9c8d-b1fd8216c686',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   '7sX4jhkTv0zj0lB': {'name': 'Spring blossom',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'haXtN_r03_d18'},
#    'picture': '',
#    'image': 'adfa9c3e-e9aa-4b65-b9d3-c5b2c0576715',
#    'lastupdated': '2023-09-22T08:40:27',
#    'version': 2},
#   'hY5GeC5kCr0ydWQ': {'name': 'Mad Purple ',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'TdfKH_r03_d99'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:28',
#    'version': 2},
#   'Vtqax92YK-9nHir': {'name': 'Mad Pink',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'Uvzqb_r03_d45'},
#    'picture': '',
#    'image': 'e4ee61c3-ecdd-4005-b483-58207e693258',
#    'lastupdated': '2023-09-22T08:40:27',
#    'version': 2},
#   'sVUlCRhaFS85Nix': {'name': 'ting',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'diGvR_r03_d99'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:27',
#    'version': 2},
#   'Js1oroEj8q4EjQa': {'name': 'New',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'v3eo9_r03'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:22',
#    'version': 2},
#   'oyx5RpsljCsvWV7': {'name': 'Read',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'EwnS4_r04_d02'},
#    'picture': '',
#    'image': 'e101a77f-9984-4f61-aac8-15741983c656',
#    'lastupdated': '2023-09-22T08:40:22',
#    'version': 2},
#   'hkKeT9DXWh8r9Mm': {'name': 'Concentrate',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'NhqxG_r04_d03'},
#    'picture': '',
#    'image': 'b90c8900-a6b7-422c-a5d3-e170187dbf8c',
#    'lastupdated': '2023-09-22T08:40:21',
#    'version': 2},
#   'csT0117g60bZiMt': {'name': 'Mountain breeze',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'Ev1zh_r01_d34'},
#    'picture': '',
#    'image': '53742ab5-a15d-457d-84c4-0303acd25c81',
#    'lastupdated': '2023-09-22T08:40:22',
#    'version': 2},
#   'y11xOanWbtAjLM-': {'name': 'Bright',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'nTxDf_r04_d05'},
#    'picture': '',
#    'image': '732ff1d9-76a7-4630-aad0-c8acc499bb0b',
#    'lastupdated': '2023-09-22T08:40:21',
#    'version': 2},
#   'ZJs1Zsl3AL8jXRd': {'name': 'Dimmed',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'ChYEd_r04_d06'},
#    'picture': '',
#    'image': '8c74b9ba-6e89-4083-a2a7-b10a1e566fed',
#    'lastupdated': '2023-09-22T08:40:25',
#    'version': 2},
#   'PjsWEsjdk-gQ2Pj': {'name': 'Ruby glow 2',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'dw5nu_r04_d36'},
#    'picture': '',
#    'image': 'edd77f6a-0198-44ac-b7c0-465dbd3d8707',
#    'lastupdated': '2023-09-22T08:40:22',
#    'version': 2},
#   'BYmwYn4J3uzerEe': {'name': 'Savanna sunset',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'j24Rc_r04_d15'},
#    'picture': '',
#    'image': '4f2ed241-5aea-4c9d-8028-55d2b111e06f',
#    'lastupdated': '2023-09-22T08:40:20',
#    'version': 2},
#   '-eKavywB7hBowKR': {'name': 'Tropical twilight',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'myzd2_r04_d16'},
#    'picture': '',
#    'image': 'a6a03e6a-fe6e-45bc-b686-878137f3ba91',
#    'lastupdated': '2023-09-22T08:40:22',
#    'version': 2},
#   'SANGHkh39j1QMAc': {'name': 'Arctic aurora',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'Zqyw7_r04_d17'},
#    'picture': '',
#    'image': '1e42b2e8-d02e-40d2-9c8d-b1fd8216c686',
#    'lastupdated': '2023-09-22T08:40:22',
#    'version': 2},
#   '30yqlLoD9MwJHoV': {'name': 'Spring blossom',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'N2jTd_r04_d18'},
#    'picture': '',
#    'image': 'adfa9c3e-e9aa-4b65-b9d3-c5b2c0576715',
#    'lastupdated': '2023-09-22T08:40:24',
#    'version': 2},
#   'x68K0jRP-S7MCz8': {'name': 'Chill ting',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'rwecW_r04'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:21',
#    'version': 2},
#   '-5eRsNlhL3ApNOM': {'name': 'Sleep',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'U1Xgt_r04'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:24',
#    'version': 2},
#   'Ifk5YHsTP7Zkz10': {'name': 'Mad',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'MVIZn_r04_d99'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:22',
#    'version': 2},
#   'g0tipkNLyukN7uw': {'name': 'On',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'utzbl_r04'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:21',
#    'version': 2},
#   'hAub93YPSo9U1YE': {'name': 'Blood moon',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'NUsBP_r03_d51'},
#    'picture': '',
#    'image': '324509da-25d2-4d22-abab-e9091c0efb37',
#    'lastupdated': '2023-09-22T08:40:24',
#    'version': 2},
#   'Uv6ZSPYsL8atP5U': {'name': 'Blood moon',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': '1m354_r01_d51'},
#    'picture': '',
#    'image': '324509da-25d2-4d22-abab-e9091c0efb37',
#    'lastupdated': '2023-09-22T08:40:21',
#    'version': 2},
#   'KRcLpvbl0pWyqG4': {'name': 'Candle lights',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'fOveJ_r01'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:23',
#    'version': 2},
#   'BMcb3dhBjaIt15d': {'name': 'Candle lights',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': '4WB7n_r03'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:22',
#    'version': 2},
#   'kjpHl2qq6y1IRy5': {'name': 'Glitz and glam',
#    'type': 'GroupScene',
#    'group': '4',
#    'lights': ['8'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'pzuUc_r04'},
#    'picture': '',
#    'image': 'df93ccf7-8928-41eb-af11-eefdcffbb06a',
#    'lastupdated': '2023-09-22T08:40:23',
#    'version': 2},
#   'A09L3c1la5a4Que': {'name': 'Night light',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': '9uDx2_r01'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:23',
#    'version': 2},
#   'psNjizkuhF8xeOh': {'name': 'Hal',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'yaUzm_r01'},
#    'picture': '',
#    'image': '10f1768a-5872-4b6f-bb6c-4d2db7bd2eae',
#    'lastupdated': '2023-09-22T08:40:23',
#    'version': 2},
#   'hchHtmDT4m6Z4JK': {'name': 'Hal',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'DHZC0_r03'},
#    'picture': '',
#    'image': '10f1768a-5872-4b6f-bb6c-4d2db7bd2eae',
#    'lastupdated': '2023-09-22T08:40:24',
#    'version': 2},
#   '0g8zR4ejSqYj4H6': {'name': 'Galaxy',
#    'type': 'GroupScene',
#    'group': '3',
#    'lights': ['5', '6'],
#    'owner': '031ff7e5-fba2-4979-91d4-0658b35ac950',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'fOKp9_r03_d49'},
#    'picture': '',
#    'image': '9e1d16f5-f391-4306-a6d3-d15bca61eb56',
#    'lastupdated': '2023-09-22T08:40:24',
#    'version': 2},
#   'hwyMhaUOvbvGWid': {'name': 'Police',
#    'type': 'GroupScene',
#    'group': '1',
#    'lights': ['1', '2', '4', '7'],
#    'owner': 'f3c76b7e-436e-4fa2-b165-50df0a5b0e9c',
#    'recycle': False,
#    'locked': False,
#    'appdata': {'version': 0, 'data': 'El2Gc_r01'},
#    'picture': '',
#    'lastupdated': '2023-09-22T08:40:23',
#    'version': 2}},
#  'rules': {'1': {'name': 'Salman’s iPhone',
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'created': '2019-07-13T02:53:41',
#    'lasttriggered': 'none',
#    'timestriggered': 0,
#    'status': 'enabled',
#    'recycle': False,
#    'conditions': [{'address': '/sensors/2/state/lastupdated',
#      'operator': 'dx'},
#     {'address': '/sensors/2/state/presence',
#      'operator': 'eq',
#      'value': 'true'}],
#    'actions': [{'address': '/sensors/3/state',
#      'method': 'PUT',
#      'body': {'presence': True}}]},
#   '2': {'name': 'Salman’s iPhone',
#    'owner': '12035b05-3086-43a6-89ef-08b334cfbcd5',
#    'created': '2019-07-13T02:53:41',
#    'lasttriggered': 'none',
#    'timestriggered': 0,
#    'status': 'enabled',
#    'recycle': False,
#    'conditions': [{'address': '/sensors/2/state/lastupdated',
#      'operator': 'dx'},
#     {'address': '/sensors/2/state/presence',
#      'operator': 'eq',
#      'value': 'false'}],
#    'actions': [{'address': '/sensors/3/state',
#      'method': 'PUT',
#      'body': {'presence': False}}]},
#   '3': {'name': '27:',
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'created': '2019-11-30T07:49:14',
#    'lasttriggered': 'none',
#    'timestriggered': 0,
#    'status': 'enabled',
#    'recycle': True,
#    'conditions': [{'address': '/sensors/7/state/status',
#      'operator': 'eq',
#      'value': '1'},
#     {'address': '/sensors/7/state/lastupdated', 'operator': 'dx'}],
#    'actions': [{'address': '/scenes/Oy3N5MW4KFBXGuC',
#      'method': 'PUT',
#      'body': {'storelightstate': True}},
#     {'address': '/groups/1/action',
#      'method': 'PUT',
#      'body': {'bri': 191,
#       'ct': 454,
#       'on': True,
#       'transitiontime': 10,
#       'xy': [0.561, 0.4042]}}]},
#   '4': {'name': '28:',
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'created': '2019-11-30T07:49:15',
#    'lasttriggered': 'none',
#    'timestriggered': 0,
#    'status': 'enabled',
#    'recycle': True,
#    'conditions': [{'address': '/sensors/7/state/status',
#      'operator': 'eq',
#      'value': '1'},
#     {'address': '/sensors/7/state/lastupdated',
#      'operator': 'ddx',
#      'value': 'PT00:00:01'}],
#    'actions': [{'address': '/schedules/1',
#      'method': 'PUT',
#      'body': {'status': 'enabled'}},
#     {'address': '/schedules/2',
#      'method': 'PUT',
#      'body': {'status': 'enabled'}},
#     {'address': '/schedules/3',
#      'method': 'PUT',
#      'body': {'status': 'enabled'}},
#     {'address': '/schedules/4',
#      'method': 'PUT',
#      'body': {'status': 'enabled'}},
#     {'address': '/schedules/5',
#      'method': 'PUT',
#      'body': {'status': 'enabled'}}]},
#   '5': {'name': '29:',
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'created': '2019-11-30T07:49:15',
#    'lasttriggered': 'none',
#    'timestriggered': 0,
#    'status': 'enabled',
#    'recycle': True,
#    'conditions': [{'address': '/sensors/7/state/status',
#      'operator': 'eq',
#      'value': '0'},
#     {'address': '/sensors/7/state/lastupdated', 'operator': 'dx'}],
#    'actions': [{'address': '/schedules/1',
#      'method': 'PUT',
#      'body': {'status': 'disabled'}},
#     {'address': '/schedules/2',
#      'method': 'PUT',
#      'body': {'status': 'disabled'}},
#     {'address': '/schedules/3',
#      'method': 'PUT',
#      'body': {'status': 'disabled'}},
#     {'address': '/schedules/4',
#      'method': 'PUT',
#      'body': {'status': 'disabled'}},
#     {'address': '/schedules/5',
#      'method': 'PUT',
#      'body': {'status': 'disabled'}}]},
#   '6': {'name': '30:',
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'created': '2019-11-30T07:49:15',
#    'lasttriggered': 'none',
#    'timestriggered': 0,
#    'status': 'enabled',
#    'recycle': True,
#    'conditions': [{'address': '/sensors/7/state/status',
#      'operator': 'eq',
#      'value': '0'},
#     {'address': '/sensors/7/state/lastupdated', 'operator': 'dx'},
#     {'address': '/groups/1/state/any_on', 'operator': 'eq', 'value': 'true'}],
#    'actions': [{'address': '/groups/1/action',
#      'method': 'PUT',
#      'body': {'scene': 'Oy3N5MW4KFBXGuC'}}]},
#   '7': {'name': '31:',
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'created': '2019-11-30T07:49:16',
#    'lasttriggered': 'none',
#    'timestriggered': 0,
#    'status': 'enabled',
#    'recycle': True,
#    'conditions': [{'address': '/groups/1/state/any_on',
#      'operator': 'eq',
#      'value': 'false'},
#     {'address': '/groups/1/state/any_on', 'operator': 'dx'},
#     {'address': '/sensors/7/state/status', 'operator': 'gt', 'value': '0'}],
#    'actions': [{'address': '/sensors/7/state',
#      'method': 'PUT',
#      'body': {'status': 0}}]}},
#  'sensors': {'1': {'state': {'daylight': False,
#     'lastupdated': '2023-09-23T22:44:00'},
#    'config': {'on': True,
#     'configured': True,
#     'sunriseoffset': 30,
#     'sunsetoffset': -30},
#    'name': 'Daylight',
#    'type': 'Daylight',
#    'modelid': 'PHDL00',
#    'manufacturername': 'Signify Netherlands B.V.',
#    'swversion': '1.0'},
#   '2': {'state': {'presence': True, 'lastupdated': '2020-04-06T07:12:23'},
#    'config': {'on': True, 'reachable': True},
#    'name': 'Salman’s iPhone',
#    'type': 'Geofence',
#    'modelid': 'HA_GEOFENCE',
#    'manufacturername': 'Philips',
#    'swversion': '1.0',
#    'uniqueid': 'L_02_dsHYW',
#    'recycle': False},
#   '3': {'state': {'presence': True, 'lastupdated': '2020-04-06T07:12:23'},
#    'config': {'on': True, 'reachable': True},
#    'name': 'HomeAway',
#    'type': 'CLIPPresence',
#    'modelid': 'HOMEAWAY',
#    'manufacturername': 'Philips',
#    'swversion': '1.0',
#    'uniqueid': 'L_01_ga3MN',
#    'recycle': False},
#   '7': {'state': {'status': 0, 'lastupdated': '2019-11-30T07:49:31'},
#    'config': {'on': True, 'reachable': True},
#    'name': 'Play and stop',
#    'type': 'CLIPGenericStatus',
#    'modelid': 'HUELABSVTOGGLE',
#    'manufacturername': 'Philips',
#    'swversion': '2.0',
#    'uniqueid': '2:0:829f-a922-41d5-893c',
#    'recycle': True}},
#  'resourcelinks': {'50053': {'name': 'Candlelight romance',
#    'description': 'NP3ZiWKrefqubQdzYnxLgg:0:Kj6wOiD7kfYPd0xjso2ArzYCWi4',
#    'type': 'Link',
#    'classid': 2,
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'recycle': True,
#    'links': ['/rules/7',
#     '/rules/6',
#     '/rules/5',
#     '/rules/4',
#     '/rules/3',
#     '/schedules/5',
#     '/schedules/4',
#     '/schedules/3',
#     '/schedules/2',
#     '/schedules/1',
#     '/groups/1',
#     '/scenes/Vj4Ab8W1QTNMORL',
#     '/scenes/bYuaqYrg1aqtwIE',
#     '/scenes/OqtipB0Ni-FkLbZ',
#     '/scenes/vY10U4VToDHaESy',
#     '/scenes/Oy3N5MW4KFBXGuC',
#     '/sensors/7']},
#   '64602': {'name': 'HueLabs 2.0',
#    'description': 'All installed formulas',
#    'type': 'Link',
#    'classid': 1,
#    'owner': '4bf7666b-f913-418f-9167-903f7b9b1d67',
#    'recycle': False,
#    'links': ['/resourcelinks/50053']}}}

# %%
lights = b.get_light_objects('id')
lights

# %%
b.set_light(1, 'bri', 0)
b.set_light(2, 'bri', 0)

# %%
b.set_light( [1,2], 'on', True)

# %%
import random
lights = b.get_light_objects()
lights=lights[2]
lights.xy = [random.random(),random.random()]

# %%
b.set_light( [1,2], 'on', False)

# %%
bedroom=b.get_group(1)
for light in bedroom:
    light.on=True

# %%
b.set_light(2, 'bri', 254)

# %%
light_names = b.get_light_objects('name')
light_names

# %% [markdown]
# Living room

# %%
for light in b.get_group(3):
    p=b.get_light_objects
    p.xy=([random.random(),random.random()])

# %%
b.get_light('Living room Light')

command =  {'transitiontime' : 10, 'on' : True, 'bri' : 254}
b.set_light('Living room Light', command)

b.set_light('Living room Light 2','on',False)

# %%
lights = b.get_light_objects('id')
lights

# %%
lights = b.get_light_objects('id')
lights[5].name
lights[5].brightness = 127

# %%
light_names = b.get_light_objects('name')
b.set_light('Living room Light 2','on',True)
light_names['Living room Light 2'].brightness = 1

# %%
b.set_light('Living room Light 2','on',True)

# %%
b.get_group(3,'lights')
living_room= b.set_group(3,'on',False)

# %%
lights=b.get_light_objects('name')
lights

# %%
b.get_group(3)

# %%
from tkinter import *
from tkinter import ttk
from tkinter import simpledialog
from tkinter import messagebox
import random
import time

# %%
from phue import Bridge
from tkinter import *
import tkinter as tk
from tkinter import ttk
from tkinter import simpledialog
from tkinter import messagebox
import random
import time
from PIL import Image, ImageTk
from tkinter import colorchooser


#link bridge 
b = Bridge('192.168.0.151')
b.connect()
b.get_api()


#Function defs

#LIVING ROOM FUNCTIONS
def livingroom_on():
    b.set_group(3,'on',True)

def livingroom_off():
    b.set_group(3,'on',False)


def livingroom_dimmer():
    #new window
    new_window = Tk()
    new_window.title("Living Room Dimmer Window")
    new_window.geometry('200x200')
    scale = Scale(new_window, from_=0, to=254)
    scale.grid(row=1,column=1)
    current_bright=b.get_group(3, 'bri')
    scale.set(current_bright)


    def get_scale():
        brightness=scale.get()
        brightness=int(brightness)
        print(brightness)
        scale_get.grid(row=2,column=1)
        b.set_group(3,'on',True) #turn on lights
        b.set_light(6, 'bri', brightness) #adjust brighntess
        b.set_light(5, 'bri', brightness)


    scale_get = tk.Button(new_window, text="Okay", command=get_scale)
    scale_get.grid(row=2,column=1)

#SALMAN BEDROOM FUNCTIONS
def salmanroom_on():
    b.set_group(1,'on',True)

def salmanroom_off():
    b.set_group(1,'on',False)

def salman_dimmer():
    #new window
    new_window = Tk()
    new_window.title("Salman Bedroom Dimmer Window")
    new_window.geometry('200x200')
    scale = Scale(new_window, from_=0, to=254)
    scale.grid(row=1,column=1)
    current_bright=b.get_group(1, 'bri')
    scale.set(current_bright)


    def get_scale():
        brightness=scale.get()
        brightness=int(brightness)
        print(brightness)
        scale_get.grid(row=2,column=1)
        b.set_group(1,'on',True) #turn on lights
        b.set_light(2, 'bri', brightness) #adjust brighntess
        b.set_light(4, 'bri', brightness)
        b.set_light(1, 'bri', brightness)
        b.set_light(7, 'bri', brightness)

    scale_get = tk.Button(new_window, text="Okay", command=get_scale)
    scale_get.grid(row=2,column=1)




def salman_party():    
    global decider
    decider = simpledialog.askstring("Input", "Enter 1 to start حفلة مود , Enter 0 stop:")
    decider=int(decider)
    
    x=decider
    while x>0:
        b.set_light(2,'xy',[random.random(),random.random()])
        b.set_light(4,'xy',[random.random(),random.random()])
        b.set_light(1,'xy',[random.random(),random.random()])
        b.set_light(7,'xy',[random.random(),random.random()])
        



def party_window():
    new_window = Tk()
    new_window.title("حفلة Window")
    party_button = tk.Button(new_window, text="حفلة مود", command=salman_party)
    party_button.pack()
    def stop_party():
        global decider
        decider=1
    stop_button = tk.Button(new_window, text="stop حفلة مود", command=stop_party)
    stop_button.pack()


#AHMED BEDROOM FUNCTION
def ahmedroom_on():
    b.set_group(4,'on',True)

def ahmedroom_off():
    b.set_group(4,'on',False)

def ahmed_dimmer():
    #new window
    new_window = Tk()
    new_window.title("Ahmed Bedroom Dimmer Window")
    new_window.geometry('200x200')
    scale = Scale(new_window, from_=0, to=254)
    scale.grid(row=1,column=1)
    current_bright=b.get_group(4, 'bri')
    scale.set(current_bright)
    
    def get_scale():
        brightness=scale.get()
        brightness=int(brightness)
        print(brightness)
        scale_get.grid(row=2,column=1)
        b.set_group(4,'on',True) #turn on lights
        b.set_light(8, 'bri', brightness) #adjust brighntess


    scale_get = tk.Button(new_window, text="Okay", command=get_scale)
    scale_get.grid(row=2,column=1)


#ALL LIGHTS FUNCTION
def all_on():
    b.set_group(1,'on',True)
    b.set_group(3,'on',True)
    b.set_group(4,'on',True)

def all_off():
    b.set_group(1,'on',False)
    b.set_group(3,'on',False)
    b.set_group(4,'on',False)



                        #COLORS FUNCTION
def color_window():
    new_window = Tk()
    new_window.title("Color Window")
    
    label = ttk.Label(new_window, text="Select a Room:")
    label.pack()
    
    rooms = {'Salman Bedroom': ['1', '2', '4', '7'],
            'Living Room': ['Light 5', 'Light 6'],
            'Afro Bedroom': ['Light 8']
            }
    combo = ttk.Combobox(new_window, values=list(rooms.keys()))
    combo.pack()
    def get_selected_value():
        global selected_value
        selected_value = combo.get()
        print("Selected Value:", selected_value)
        print(b.get_group(selected_value))

    button = tk.Button(new_window, text="Confrim", command=get_selected_value)
    button.pack()





    #RGB CONVERSTION
    def rgb_to_xy(red, green, blue):

        # gamma correction
        red = pow((red + 0.055) / (1.0 + 0.055), 2.4) if red > 0.04045 else (red / 12.92)
        green = pow((green + 0.055) / (1.0 + 0.055), 2.4) if green > 0.04045 else (green / 12.92)
        blue =  pow((blue + 0.055) / (1.0 + 0.055), 2.4) if blue > 0.04045 else (blue / 12.92)

        # convert rgb to xyz
        x = red * 0.649926 + green * 0.103455 + blue * 0.197109
        y = red * 0.234327 + green * 0.743075 + blue * 0.022598
        z = green * 0.053077 + blue * 1.035763

        # convert xyz to xy
        x = x / (x + y + z)
        y = y / (x + y + z)

        # TODO check color gamut if known
        
        return [x, y]

    def choose_color():
    
        color_code = colorchooser.askcolor(title ="Choose color")
        rgb_color = color_code[0]
        #print(rgb_color[0])
        #print(rgb_color[1])
        #print(rgb_color[2])
        xy_color=rgb_to_xy(rgb_color[0],rgb_color[1],rgb_color[2])
        #print("XY Color:", xy_color)
        selected_value_gid= b.get_group_id_by_name(selected_value)
        print(selected_value_gid)
        b.set_group(selected_value_gid,'xy',xy_color)
    colors = ttk.Button(new_window, text="Colors", command=choose_color,width=7)
    colors.pack()


    
    

#OVERVIEW FUNCTION (QUICK STATUS)
def status(g_id):
    if b.get_group(g_id,'on')==True:
        bri=b.get_group(g_id,'bri')
        status = f'Lights are on, Brightness is {bri}'
        return status

    else:
        status='Lights are off'
        return status

#MAIN WINDOW
root=Tk()
root.title("Smart Home Control")

#frm = ttk.Frame(root, padding=10)
#frm.grid()


                    #OVERVIEW SECTION
#OVERVIEW LABEL
overview_label = tk.Label(root, text="Overview",fg='#5f43b2')
overview_label.grid(row=0, column=1)

#IMG 1
image_path = '/Users/salman/Desktop/Github/IMG_6384.jpg'

original_image = Image.open(image_path)
corrected_image = original_image.rotate(270, expand=True) 
new_width = 50  
new_height = 50 
resized_image = corrected_image.resize((new_width, new_height), Image.ANTIALIAS) 

photo = ImageTk.PhotoImage(resized_image)

label_image = tk.Label(root, image=photo)
label_image.grid(row=2, column=0,padx=10,pady=10)

#OVERVIEW STATUS SALMAN
sb_status_label = tk.Label(root, text="Salman Bedroom",fg='#5f43b2')
sb_status_label.grid(row=3, column=0)

status_label = tk.Label(root, text="", width=30)
status_label.grid(row=4,column=0)

def update_status():
    get_status = status(1)
    status_label.config(text=get_status)
    root.after(1000, update_status) 
update_status()



#IMG 2
image_path2 = '/Users/salman/Desktop/Github/IMG_8377.jpg'

original_image2 = Image.open(image_path2)
corrected_image2 = original_image2.rotate(360, expand=True)  
new_width = 50  
new_height = 50 
resized_image2 = corrected_image2.resize((new_width, new_height), Image.ANTIALIAS) 

photo2 = ImageTk.PhotoImage(resized_image2)

label_image2 = tk.Label(root, image=photo2)
label_image2.grid(row=2, column=1,padx=10,pady=10)
#OVERVIEW STATUS AHMED
ab_status_label = tk.Label(root, text="Ahmed Bedroom",fg='#5f43b2')
ab_status_label.grid(row=3, column=1)

status_label_ab = tk.Label(root, text="", width=30)
status_label_ab.grid(row=4,column=1)


def update_status_ab():
    get_status_ab = status(4)
    status_label_ab.config(text=get_status_ab)
    root.after(1000, update_status_ab) 
update_status_ab()


#IMG 3
image_path3 = '/Users/salman/Desktop/Github/lito.jpg'

original_image3 = Image.open(image_path3)
corrected_image3 = original_image3.rotate(360, expand=True)  

new_width = 50  
new_height = 50 
resized_image3 = corrected_image3.resize((new_width, new_height), Image.ANTIALIAS) 

photo3 = ImageTk.PhotoImage(resized_image3)

label_image3 = tk.Label(root, image=photo3)
label_image3.grid(row=2, column=3,padx=10,pady=10)

#OVERVIEW STATUS LIVING ROOM
lv_status_label = tk.Label(root, text="Living Room (Ales Room)",fg='#5f43b2')
lv_status_label.grid(row=3, column=3)

status_label_lv = tk.Label(root, text="", width=30)
status_label_lv.grid(row=4,column=3)

def update_status_lv():
    get_status_lv = status(3)
    status_label_lv.config(text=get_status_lv)
    root.after(1000, update_status_lv) 
update_status_lv()


#LIVING ROOM LABELS
lv_label = tk.Label(root, text="Living Room", fg='#5f43b2')
lv_label.grid(row=5, column=0)

lv_on_b = tk.Button(root, text="ON", command=livingroom_on,width=7)
lv_on_b.grid(row=6, column=1)

lv_of_b = tk.Button(root, text="OFF", command=livingroom_off,width=7)
lv_of_b.grid(row=7, column=1)

lv_dim_b = tk.Button(root, text="Dimmer", command=livingroom_dimmer,width=7)
lv_dim_b.grid(row=8,column=1)

#SALMAN BEDROOM LABELS
sb_label = tk.Label(root, text="Salmans Bedroom",fg='#5f43b2')
sb_label.grid(row=9, column=0)

sb_on_b = tk.Button(root, text="ON", command=salmanroom_on,width=7)
sb_on_b.grid(row=10, column=1)

sb_of_b = tk.Button(root, text="OFF", command=salmanroom_off,width=7)
sb_of_b.grid(row=11, column=1)

sb_dim_b = tk.Button(root, text="Dimmer", command=salman_dimmer,width=7)
sb_dim_b.grid(row=12, column=1)

sb_party_b = tk.Button(root, text="حفلة مود", command=party_window,width=7)
sb_party_b.grid(row=13, column=1)

#AHMED BEDROOM LABELS
ab_label = tk.Label(root, text="Afro Bedroom", fg='#5f43b2')
ab_label.grid(row=14, column=0)

ab_on_b = tk.Button(root, text="ON", command=ahmedroom_on,width=7)
ab_on_b.grid(row=15, column=1)

ab_of_b = tk.Button(root, text="OFF", command=ahmedroom_off,width=7)
ab_of_b.grid(row=16, column=1)

ab_dim_b = tk.Button(root, text="Dimmer", command=ahmed_dimmer,width=7)
ab_dim_b.grid(row=17,column=1)

#ALL LIGHTS LABELS
all_label = tk.Label(root, text="All lights",fg='#5f43b2')
all_label.grid(row=18, column=0)

all_on_b = tk.Button(root, text="ON", command=all_on,width=7)
all_on_b.grid(row=19, column=1)

all_of_b = tk.Button(root, text="OFF", command=all_off,width=7)
all_of_b.grid(row=20, column=1)

#COLORS LABELS  
colors_label = tk.Label(root, text="Change Colors",fg='#5f43b2')
colors_label.grid(row=21, column=0)


colors_b = tk.Button(root, text="Colors", command=color_window,width=7)
colors_b.grid(row=22, column=1)


root.mainloop()
# Out:
# /var/folders/wb/kl3ybdg92r1ch0l79d1b67dw0000gn/T/ipykernel_19438/2444603868.py:256: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_image = corrected_image.resize((new_width, new_height), Image.ANTIALIAS)
# /var/folders/wb/kl3ybdg92r1ch0l79d1b67dw0000gn/T/ipykernel_19438/2444603868.py:285: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_image2 = corrected_image2.resize((new_width, new_height), Image.ANTIALIAS)
# /var/folders/wb/kl3ybdg92r1ch0l79d1b67dw0000gn/T/ipykernel_19438/2444603868.py:314: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   resized_image3 = corrected_image3.resize((new_width, new_height), Image.ANTIALIAS)
# 37
# 97
# Selected Value: Afro Bedroom
# {'name': 'Afro Bedroom', 'lights': ['8'], 'sensors': [], 'type': 'Room', 'state': {'all_on': True, 'any_on': True}, 'recycle': False, 'class': 'Bedroom', 'action': {'on': True, 'bri': 205, 'hue': 7409, 'sat': 225, 'effect': 'none', 'xy': [0.5223, 0.4165], 'ct': 488, 'alert': 'select', 'colormode': 'xy'}}
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "/var/folders/wb/kl3ybdg92r1ch0l79d1b67dw0000gn/T/ipykernel_19438/2444603868.py", line 213, in choose_color
#     xy_color=rgb_to_xy(rgb_color[0],rgb_color[1],rgb_color[2])
# TypeError: 'NoneType' object is not subscriptable
# Selected Value: Living Room
# {'name': 'Living Room', 'lights': ['6', '5'], 'sensors': [], 'type': 'Room', 'state': {'all_on': True, 'any_on': True}, 'recycle': False, 'class': 'Living room', 'action': {'on': True, 'bri': 97, 'hue': 55921, 'sat': 209, 'effect': 'none', 'xy': [0.4053, 0.2085], 'ct': 283, 'alert': 'select', 'colormode': 'xy'}}
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
